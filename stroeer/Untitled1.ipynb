# %%
from store.sample import placements
import json
import random
#placements = [['yieldlove.com_d_300x250_1', '300x250, 970x250, 728x90'],['venezuela.com_m_300x250_1', '300x250, 300x600'], ['brasil.com_m_300x250_1', '300x250, 300x600'],['ecuador_m_300x250_1', '300x250, 300x600']]

# %%
placements.sort()
main_sample = {"website":"xxxxx",
"desktop":[
{"name":"yieldlove.com_d_300x250_1",
"sizes":["300x250"],
"created": "no"
}
],
"mobile":[
{"name":"yieldlove.com_m_300x250_1",
"sizes":["300x250"],
"created": "no"
}
]
}
placement_sample = {"name":"yieldlove.com_d_300x250_1",
"sizes":["300x250"],
"created": "no"
}
print(placement_sample)
sizes = ['300x250','320x50','320x100','320x75','320x150']
# Out:
# {'name': 'yieldlove.com_d_300x250_1', 'sizes': ['300x250'], 'created': 'no'}

# %%
def transforming_placements_json(placements)
    mother_placement = []
    for placement in placements:
        son = json.dumps({'name': placement[0], 'sizes':placement[1], 'created': 'no'})
        son = json.loads(son)
        mother_placement.append(son)
    return mother_placement


def transforing_websites_json(placements):
    websites = []
    mother_website = []
    [websites.append(placement[0][:placement[0].find('_')]) for placement in placements if placement[0][:placement[0].find('_')] not in websites]
    for website in websites:
        web_json = json.dumps({'website': website ,'desktop':[],'mobile':[]})
        web_json = json.loads(web_json)
        mother_website.append(web_json)
    return mother_website


def merging_placements_websites(websites, placements)
    for website in websites:
        [website['desktop'].append(placement) for placement in placements if website['website'] in placement['name'] and '_d_' in placement['name']]
        [website['mobile'].append(placement) for placement in placements if website['website'] in placement['name'] and '_m_' in placement['name']]

# %%
for website in mother_website:
    [website['desktop'].append(placement) for placement in mother_placement if website['website'] in placement['name'] and '_d_' in placement['name']]
    [website['mobile'].append(placement) for placement in mother_placement if website['website'] in placement['name'] and '_m_' in placement['name']]

# %%
mother_website
# Out:
# [{'website': '1001-rimes.com',
#   'desktop': [{'name': '1001-rimes.com_d_300x600_1',
#     'sizes': '300x250, 970x250, 728x90',
#     'created': 'no'},
#    {'name': '1001-rimes.com_d_728x90_1',
#     'sizes': '300x250, 970x250, 728x90',
#     'created': 'no'}],
#   'mobile': []},
#  {'website': '1mot.net',
#   'desktop': [],
#   'mobile': [{'name': '1mot.net_m_300x250_1',
#     'sizes': '300x250, 970x250, 728x90',
#     'created': 'no'}]},
#  {'website': '24sata.hr',
#   'desktop': [{'name': '24sata.hr_d_300x250_1',
#     'sizes': '300x250, 970x250, 728x90',
#     'created': 'no'},
#    {'name': '24sata.hr_d_970x250_2',
#     'sizes': '300x250, 970x250, 728x90',
#     'created': 'no'},
#    {'name': '24sata.hr_d_970x250_4',
#     'sizes': '300x250, 970x250, 728x90',
#     'created': 'no'}],
#   'mobile': [{'name': '24sata.hr_m_320x100_1',
#     'sizes': '300x250, 970x250, 728x90',
#     'created': 'no'},
#    {'name': '24sata.hr_m_336x280_3',
# ...

# %%
# Out:
# 1001-rimes.com_d_300x600_1
# 1001-rimes.com_d_728x90_1
# 1mot.net_m_300x250_1
# 24sata.hr_d_300x250_1
# 24sata.hr_d_970x250_2
# 24sata.hr_d_970x250_4
# 24sata.hr_m_320x100_1
# 24sata.hr_m_336x280_3
# 24sata.hr_m_336x280_4
# aachener-nachrichten.de_d_300x600_1
# aachener-nachrichten.de_d_300x600_2
# aachener-nachrichten.de_d_970x250_1
# aachener-nachrichten.de_m_320x250_1
# aachener-nachrichten.de_m_320x600_1
# aachener-zeitung.de_d_300x600_1
# aachener-zeitung.de_d_300x600_2
# aachener-zeitung.de_d_970x250_1
# aachener-zeitung.de_m_320x250_1
# aachener-zeitung.de_m_320x600_1
# abendblatt.de_d_300x250_1
# abendblatt.de_m_300x600_2
# abendblatt.de_m_336x280_1
# abendblatt.de_m_336x280_4
# actu17.fr_d_300x250_1
# actu17.fr_d_300x250_3
# actu17.fr_d_300x600_1
# actu17.fr_m_300x250_1
# actu17.fr_m_300x250_3
# actu17.fr_m_320x100_1
# actualitte.com_d_300x600_1
# aero.de_d_300x250_1
# aero.de_d_300x600_1
# aero.de_d_970x250_1
# aero.de_m_320x250_1
# aero.de_m_320x250_2
# ...

# %%
[websites.append([placement[0][:placement.find('_')]) for placement in placements if placement[0][:placement.find('_')] not in websites])
# Out:
#   File "<ipython-input-25-1f909073786a>", line 1
#     [websites.append([placement[0][:placement.find('_')]) for placement in placements if placement[0][:placement.find('_')] not in websites])
#                                                         ^
# SyntaxError: invalid syntax

# %%
[websites.append(placement[0][:placement[0].find('_')]) for placement in placements if placement[0][:placement[0].find('_')] not in websites]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
websites
# Out:
# ['1001-rimes.com',
#  '1mot.net',
#  '24sata.hr',
#  'aachener-nachrichten.de',
#  'aachener-zeitung.de',
#  'abendblatt.de',
#  'actu17.fr',
#  'actualitte.com',
#  'aero.de',
#  'agenda-loto.net',
#  'all-in.de',
#  'allgemeine-zeitung.de',
#  'alpenvereinaktiv.com',
#  'alpin.de',
#  'animecharactersdatabase.com',
#  'animedigitalnetwork.fr',
#  'astro.com',
#  'astroportal.com',
#  'astrowoche.wunderweib.de',
#  'auskunft.de',
#  'auto-motor-und-sport.de',
#  'autogazette.de',
#  'autoguru.de',
#  'autozeitung.de',
#  'babelio.com',
#  'barcode-generator.de',
#  'beluka.de',
#  'berliner-kurier.de',
#  'berliner-zeitung.de',
#  'bestwordlist.com',
#  'bigfm.de',
#  'bisafans.de',
#  'bluray-disc.de',
#  'bonjourdefrance.com',
#  'braceletbook.com',
#  'braunschweiger-zeitung.de',
#  'bravo.de',
#  'briskoda.net',
#  'brocabrac.fr',
#  'buffed.de',
#  'capeutservir.com',
#  'caracteristicas.co',
#  'caravaning.de',
#  'cataloguemate.fr',
#  'chirurgie-portal.de',
# ...

# %%
for p in mother_placement:
    print(type(p))
    print(p['name'])
    break
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-a1a48883ee94> in <module>
#       1 for p in mother_placement:
#       2     print(type(p))
# ----> 3     print(p['name'])
#       4     break
#
# TypeError: string indices must be integers

# %%
web = 'felipe.com'
a = {'website': web}
b = json.dumps({'website': web})
b = json.loads(b)

# %%
a = json.dumps({'website': web ,'desktop':[],'mobile':[]})

# %%
a
# Out:
# '{"website": "felipe.com", "desktop": [], "mobile": []}'
